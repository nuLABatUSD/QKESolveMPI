# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("R_values_test.csv", delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = np.loadtxt("R_values_test.csv", delimiter=',')
#
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/lib/npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# ...

# %%
organized_data = {}
i=0
while i<len(data-1):
    if i%2==0:
        eps = data[i][2:]
        R = data[i+1]
        organized_data[(data[i][0], data[i][1])] = [eps, R]
